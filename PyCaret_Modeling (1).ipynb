# %%
# !pip install pycaret[full]

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/elvanselvano/purwadhika-final-project/main/df_clean.csv?token=AL27OTJGKQIMLPEON2SNZD3A6ARQW')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  ...  CENSUS_BLOCK    WARD  SQUARE  QUADRANT
# 0       4          0      Warm Cool  Y  ...   004201 2006  Ward 2     152        NW
# 1       3          1  Hot Water Rad  Y  ...   004201 2006  Ward 2     152        NW
# 2       3          1  Hot Water Rad  Y  ...   004201 2006  Ward 2     152        NW
# 3       3          2  Hot Water Rad  Y  ...   004201 2006  Ward 2     152        NW
# 4       3          1  Hot Water Rad  Y  ...   004201 2005  Ward 2     152        NW
#
# [5 rows x 35 columns]

# %%
from pycaret.regression import *
reg1 = setup(df, target = 'PRICE', session_id=42, log_experiment=True, 
             experiment_name='price_modeling', use_gpu = True,
             categorical_features = ['ZIPCODE'],
             numeric_features = ['BATHRM', 'HF_BATHRM', 'BEDRM', 'SALE_NUM', 'FIREPLACES', 'USECODE'])
# Out:
#                                Description           Value
# 0                               session_id              42
# 1                                   Target           PRICE
# 2                            Original Data     (57345, 35)
# 3                           Missing Values           False
# 4                         Numeric Features              18
# 5                     Categorical Features              16
# 6                         Ordinal Features           False
# 7                High Cardinality Features           False
# 8                  High Cardinality Method            None
# 9                    Transformed Train Set   (40141, 3930)
# 10                    Transformed Test Set   (17204, 3930)
# 11                      Shuffle Train-Test            True
# 12                     Stratify Train-Test           False
# 13                          Fold Generator           KFold
# 14                             Fold Number              10
# 15                                CPU Jobs              -1
# 16                                 Use GPU            True
# 17                          Log Experiment            True
# 18                         Experiment Name  price_modeling
# 19                                     USI            164c
# 20                         Imputation Type          simple
# 21          Iterative Imputation Iteration            None
# 22                         Numeric Imputer            mean
# 23      Iterative Imputation Numeric Model            None
# 24                     Categorical Imputer        constant
# 25  Iterative Imputation Categorical Model            None
# 26           Unknown Categoricals Handling  least_frequent
# 27                               Normalize           False
# 28                        Normalize Method            None
# 29                          Transformation           False
# 30                   Transformation Method            None
# 31                                     PCA           False
# 32                              PCA Method            None
# 33                          PCA Components            None
# 34                     Ignore Low Variance           False
# 35                     Combine Rare Levels           False
# 36                    Rare Level Threshold            None
# 37                         Numeric Binning           False
# 38                         Remove Outliers           False
# 39                      Outliers Threshold            None
# 40                Remove Multicollinearity           False
# 41             Multicollinearity Threshold            None
# 42             Remove Perfect Collinearity            True
# 43                              Clustering           False
# 44                    Clustering Iteration            None
# 45                     Polynomial Features           False
# 46                       Polynomial Degree            None
# 47                    Trignometry Features           False
# 48                    Polynomial Threshold            None
# 49                          Group Features           False
# 50                       Feature Selection           False
# 51                Feature Selection Method         classic
# 52            Features Selection Threshold            None
# 53                     Feature Interaction           False
# 54                           Feature Ratio           False
# 55                   Interaction Threshold            None
# 56                        Transform Target           False
# 57                 Transform Target Method         box-cox

# %%
best_model = compare_models(fold=5)
# Out:
#                                     Model          MAE           MSE  \
# catboost               CatBoost Regressor  135247.9631  8.060230e+10
# lightgbm  Light Gradient Boosting Machine  136993.8506  8.321980e+10
# et                  Extra Trees Regressor  132103.9102  8.981125e+10
# rf                Random Forest Regressor  132952.0741  9.091479e+10
# gbr           Gradient Boosting Regressor  149235.8081  9.282317e+10
# br                         Bayesian Ridge  180808.7375  1.122814e+11
# ridge                    Ridge Regression  184026.6375  1.158716e+11
# llar         Lasso Least Angle Regression  182196.2542  1.214819e+11
# lar                Least Angle Regression  185593.1078  1.210610e+11
# omp           Orthogonal Matching Pursuit  184613.7639  1.218062e+11
# lasso                    Lasso Regression  187164.3000  1.223105e+11
# lr                      Linear Regression  193025.2688  1.251852e+11
# en                            Elastic Net  210458.1219  1.490466e+11
# dt                Decision Tree Regressor  180812.0191  1.611204e+11
# knn                 K Neighbors Regressor  231008.5188  1.793000e+11
# huber                     Huber Regressor  206815.1482  1.821622e+11
# par          Passive Aggressive Regressor  358296.2437  3.074376e+11
# xgboost         Extreme Gradient Boosting       0.0000  0.000000e+00
# ada                    AdaBoost Regressor  715305.2604  8.152634e+11
#
#                  RMSE      R2   RMSLE     MAPE  TT (Sec)
# catboost  282233.0468  0.7768  0.4616   4.6522    27.290
# lightgbm  286838.0680  0.7692  0.4664   4.7786     4.426
# et        297940.8450  0.7532  0.4605   4.4402   571.834
# rf        299730.1846  0.7504  0.4574   5.3534   387.186
# gbr       303007.3095  0.7444  0.4881   6.9223   174.186
# br        334130.3869  0.6887  0.6828   7.0283   322.746
# ridge     339650.8562  0.6776  0.6852   6.4205    10.572
# llar      346795.2980  0.6656  0.6806   7.6945    11.344
# lar       346955.4018  0.6635  0.6977   7.6956    12.098
# omp       348195.9705  0.6614  0.6942   7.9281     9.706
# lasso     349081.9000  0.6591  0.6931   6.2768    94.056
# lr        353162.4375  0.6513  0.7131   6.2666    48.000
# en        384078.4062  0.5907  0.7920  11.0533   141.838
# dt        399368.3029  0.5550  0.6128   5.0389     7.104
# knn       422494.3188  0.5015  0.6629   7.8899    54.544
# huber     424387.7613  0.5007  0.6939   4.2806   360.494
# par       541549.4648  0.1526  0.9546  25.2595    13.580
# xgboost        0.0000  0.0000  0.0000   0.0000     3.556
# ada       849169.1713 -1.5678  1.2789  45.4728   419.612

# %%
lightgbm = create_model('lightgbm')
# Out:
#               MAE           MSE         RMSE      R2   RMSLE     MAPE
# 0     138040.7731  7.521932e+10  274261.4124  0.7581  0.4551   0.5890
# 1     133124.4916  7.651028e+10  276604.9233  0.7373  0.4601   0.5917
# 2     130025.4118  5.402071e+10  232423.5639  0.8156  0.4719  37.3211
# 3     131881.2499  5.668918e+10  238094.9017  0.7916  0.4629   4.7026
# 4     143615.4787  1.688736e+11  410942.3664  0.7034  0.4408   0.4060
# 5     138876.3589  5.913999e+10  243187.1416  0.8034  0.4785   0.9231
# 6     135489.9060  6.788297e+10  260543.6137  0.8138  0.4465   1.0486
# 7     138282.4689  1.067865e+11  326782.1060  0.7803  0.4620   1.1872
# 8     136474.6548  6.288351e+10  250765.8527  0.8185  0.4854   4.4416
# 9     139226.0258  9.282980e+10  304679.8349  0.7619  0.4851   5.0226
# Mean  136503.6819  8.208359e+10  281828.5717  0.7784  0.4648   5.6234
# SD      3806.9346  3.296289e+10   51538.8316  0.0361  0.0145  10.7142

# %%
tuned_lightgbm = tune_model(lightgbm, n_iter=50, optimize = 'MAE', search_library = 'optuna')
# Out:
#               MAE           MSE         RMSE      R2   RMSLE     MAPE
# 0     131659.7154  6.467229e+10  254307.4690  0.7920  0.4553   0.5811
# 1     127472.8120  7.872404e+10  280578.0507  0.7297  0.4490   0.5910
# 2     124040.1662  5.241078e+10  228934.0029  0.8211  0.4673  33.7480
# 3     127122.9765  5.525604e+10  235066.0251  0.7968  0.4645   4.9002
# 4     139444.0278  1.642999e+11  405339.2199  0.7114  0.4326   0.3927
# 5     131170.0792  5.424878e+10  232913.6827  0.8197  0.4681   0.9361
# 6     131297.6749  6.386374e+10  252712.7716  0.8248  0.4391   0.9884
# 7     130946.5458  9.092316e+10  301534.6758  0.8129  0.4554   1.0404
# 8     131955.0099  5.893638e+10  242768.1573  0.8299  0.4791   4.5321
# 9     133208.1371  8.740782e+10  295648.1438  0.7758  0.4801   4.2138
# Mean  130831.7145  7.707429e+10  272980.2199  0.7914  0.4590   5.1924
# SD      3915.0171  3.189395e+10   50557.8048  0.0390  0.0150   9.6716

# %%
tuned_lightgbm
# Out:
# LGBMRegressor(bagging_fraction=0.6274298173596514, bagging_freq=5,
#               boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               feature_fraction=0.6347474661539554, importance_type='split',
#               learning_rate=0.03666569409336927, max_depth=-1,
#               min_child_samples=15, min_child_weight=0.001,
#               min_split_gain=0.6702337863652381, n_estimators=267, n_jobs=-1,
#               num_leaves=110, objective=None, random_state=42,
#               reg_alpha=5.455943134437243e-06, reg_lambda=7.834159286024462e-07,
#               silent=True, subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0)

# %%
plot_model(tuned_lightgbm)

# %%
plot_model(tuned_lightgbm, plot = 'error')

# %%
interpret_model(tuned_lightgbm)

# %%
save_model(tuned_lightgbm, model_name='best-model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['ZIPCODE'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['BATHRM', 'HF_BATHRM',
#                                                            'BEDRM', 'SALE_NUM',
#                                                            'FIREPLACES',
#                                                            'USECODE'],
#                                        target='PRICE', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  f...
#                                 importance_type='split',
#                                 learning_rate=0.03666569409336927, max_depth=-1,
#                                 min_child_samples=15, min_child_weight=0.001,
#                                 min_split_gain=0.6702337863652381,
#                                 n_estimators=267, n_jobs=-1, num_leaves=110,
#                                 objective=None, random_state=42,
#                                 reg_alpha=5.455943134437243e-06,
#                                 reg_lambda=7.834159286024462e-07, silent=True,
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False), 'best-model.pkl')
